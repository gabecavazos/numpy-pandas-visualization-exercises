# %%
import pandas as pd
import numpy as np
from env import user, password, host

# %%
#3
def get_db_url(user,password,host,database_name):
    url =  f'mysql+pymysql://{user}:{password}@{host}/{database_name}'
    return url

# %%
#4 create url
url = get_db_url(user, password, host, 'employees')

# %%
#5
pd.read_sql('''
SELECT * 
FROM employees 
LIMIT 5''', url)
# Out:
#    emp_no  birth_date first_name last_name gender   hire_date
# 0   10001  1953-09-02     Georgi   Facello      M  1986-06-26
# 1   10002  1964-06-02    Bezalel    Simmel      F  1985-11-21
# 2   10003  1959-12-03      Parto   Bamford      M  1986-08-28
# 3   10004  1954-05-01  Chirstian   Koblick      M  1986-12-01
# 4   10005  1955-01-21    Kyoichi  Maliniak      M  1989-09-12

# %%
#5a error message from typo in url
url = get_db_url(user, password, host, 'employee')
pd.read_sql('''
SELECT * 
FROM employees 
LIMIT 5''', url)
# Out:
# ---------------------------------------------------------------------------
# OperationalError                          Traceback (most recent call last)
# /usr/local/anaconda3/lib/python3.9/site-packages/sqlalchemy/engine/base.py in _wrap_pool_connect(self, fn, connection)
#    3279         try:
# -> 3280             return fn()
#    3281         except dialect.dbapi.Error as e:
#
# /usr/local/anaconda3/lib/python3.9/site-packages/sqlalchemy/pool/base.py in connect(self)
#     309         """
# --> 310         return _ConnectionFairy._checkout(self)
#     311
#
# /usr/local/anaconda3/lib/python3.9/site-packages/sqlalchemy/pool/base.py in _checkout(cls, pool, threadconns, fairy)
#     867         if not fairy:
# --> 868             fairy = _ConnectionRecord.checkout(pool)
#     869
#
# /usr/local/anaconda3/lib/python3.9/site-packages/sqlalchemy/pool/base.py in checkout(cls, pool)
#     475     def checkout(cls, pool):
# --> 476         rec = pool._do_get()
#     477         try:
#
# ...

# %%
#OperationalError: (pymysql.err.OperationalError) 
#(1044, "Access denied for user 'oneil_2102'@'%' to database 'employee'")

# %%
#5b typo in query
url = get_db_url(user, password, host, 'employees')
pd.read_sql('''
SELECT * 
FROM emp 
LIMIT 5''', url)

# %%
#1146, "Table 'employees.emp' doesn't exist"

# %%
#6
url = get_db_url(user, password, host, 'employees')
df1 = pd.read_sql('''
SELECT * 
FROM employees 
''', url)

# %%
url = get_db_url(user, password, host, 'employees')
df2 = pd.read_sql('''
SELECT * 
FROM titles 
''', url)

# %%
#7 number of rows and columns
df1.shape

# %%
df2.shape

# %%
#8 more info
df1.describe()

# %%
df2.describe()

# %%
#9 unique titles in titles
df2['title'].unique()

# %%
df2.title.nunique()

# %%
#10 oldest dat in to_date
df2.to_date.min()

# %%
#11 most recent date in the to_date
df2.to_date[df2.to_date != df2.to_date.max()].max()

# %% [markdown]
# ## Part 2

# %%
users = pd.DataFrame({
    'id': [1, 2, 3, 4, 5, 6],
    'name': ['bob', 'joe', 'sally', 'adam', 'jane', 'mike'],
    'role_id': [1, 2, 3, 3, np.nan, np.nan]
})
users
# Out:
#    id   name  role_id
# 0   1    bob      1.0
# 1   2    joe      2.0
# 2   3  sally      3.0
# 3   4   adam      3.0
# 4   5   jane      NaN
# 5   6   mike      NaN

# %%
roles = pd.DataFrame({
    'id': [1, 2, 3, 4],
    'name': ['admin', 'author', 'reviewer', 'commenter']
})
roles
# Out:
#    id       name
# 0   1      admin
# 1   2     author
# 2   3   reviewer
# 3   4  commenter

# %%
#1 right join
pd.merge(users,roles, how='right', left_on='role_id', right_on='id')
# Out:
#    id_x name_x  role_id  id_y     name_y
# 0   1.0    bob      1.0     1      admin
# 1   2.0    joe      2.0     2     author
# 2   3.0  sally      3.0     3   reviewer
# 3   4.0   adam      3.0     3   reviewer
# 4   NaN    NaN      NaN     4  commenter

# %%
#2 outer join
pd.merge(users,roles, how='outer', left_on='role_id', right_on='id', indicator=True)
# Out:
#    id_x name_x  role_id  id_y     name_y      _merge
# 0   1.0    bob      1.0   1.0      admin        both
# 1   2.0    joe      2.0   2.0     author        both
# 2   3.0  sally      3.0   3.0   reviewer        both
# 3   4.0   adam      3.0   3.0   reviewer        both
# 4   5.0   jane      NaN   NaN        NaN   left_only
# 5   6.0   mike      NaN   NaN        NaN   left_only
# 6   NaN    NaN      NaN   4.0  commenter  right_only

# %%
#drop fk
users = users.drop(columns='role_id')
users
# Out:
#    id   name
# 0   1    bob
# 1   2    joe
# 2   3  sally
# 3   4   adam
# 4   5   jane
# 5   6   mike

# %%
roles
# Out:
#    id       name
# 0   1      admin
# 1   2     author
# 2   3   reviewer
# 3   4  commenter

# %%
pd.merge(users,roles, how='outer', on='id')
# Out:
#    id name_x     name_y
# 0   1    bob      admin
# 1   2    joe     author
# 2   3  sally   reviewer
# 3   4   adam  commenter
# 4   5   jane        NaN
# 5   6   mike        NaN

# %%
from pydataset import data

# %%
mpg = data('mpg')

# %%
mpg
# Out:
#     manufacturer   model  displ  year  cyl       trans drv  cty  hwy fl  \
# 1           audi      a4    1.8  1999    4    auto(l5)   f   18   29  p
# 2           audi      a4    1.8  1999    4  manual(m5)   f   21   29  p
# 3           audi      a4    2.0  2008    4  manual(m6)   f   20   31  p
# 4           audi      a4    2.0  2008    4    auto(av)   f   21   30  p
# 5           audi      a4    2.8  1999    6    auto(l5)   f   16   26  p
# ..           ...     ...    ...   ...  ...         ...  ..  ...  ... ..
# 230   volkswagen  passat    2.0  2008    4    auto(s6)   f   19   28  p
# 231   volkswagen  passat    2.0  2008    4  manual(m6)   f   21   29  p
# 232   volkswagen  passat    2.8  1999    6    auto(l5)   f   16   26  p
# 233   volkswagen  passat    2.8  1999    6  manual(m5)   f   18   26  p
# 234   volkswagen  passat    3.6  2008    6    auto(s6)   f   17   26  p
#
#        class
# 1    compact
# 2    compact
# 3    compact
# 4    compact
# 5    compact
# ..       ...
# ...

# %%
#show doc
data('mpg', show_doc=True)
# Out:
# mpg
#
# PyDataset Documentation (adopted from R Documentation. The displayed examples are in R)
#
# ## Fuel economy data from 1999 and 2008 for 38 popular models of car
#
# ### Description
#
# This dataset contains a subset of the fuel economy data that the EPA makes
# available on http://fueleconomy.gov. It contains only models which had a new
# release every year between 1999 and 2008 - this was used as a proxy for the
# popularity of the car.
#
# ### Usage
#
#     data(mpg)
#
# ### Format
#
# A data frame with 234 rows and 11 variables
#
# ### Details
#
#   * manufacturer.
#
#   * model.
#
#   * displ. engine displacement, in litres
#
#   * year.
#
#   * cyl. number of cylinders
#
#   * trans. type of transmission
#
#   * drv. f = front-wheel drive, r = rear wheel drive, 4 = 4wd
#
#   * cty. city miles per gallon
#
#   * hwy. highway miles per gallon
#
#   * fl.
#
#   * class.

# %%
#rows and cols
mpg.shape
# Out:
# (234, 11)

# %%
mpg.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 234 entries, 1 to 234
# Data columns (total 11 columns):
#  #   Column        Non-Null Count  Dtype
# ---  ------        --------------  -----
#  0   manufacturer  234 non-null    object
#  1   model         234 non-null    object
#  2   displ         234 non-null    float64
#  3   year          234 non-null    int64
#  4   cyl           234 non-null    int64
#  5   trans         234 non-null    object
#  6   drv           234 non-null    object
#  7   cty           234 non-null    int64
#  8   hwy           234 non-null    int64
#  9   fl            234 non-null    object
#  10  class         234 non-null    object
# dtypes: float64(1), int64(4), object(6)
# memory usage: 21.9+ KB

# %%
#clean up
mpg = mpg.rename(columns={'class':'cls', 'cty':'city'})
mpg
# Out:
#     manufacturer   model  displ  year  cyl       trans drv  city  hwy fl  \
# 1           audi      a4    1.8  1999    4    auto(l5)   f    18   29  p
# 2           audi      a4    1.8  1999    4  manual(m5)   f    21   29  p
# 3           audi      a4    2.0  2008    4  manual(m6)   f    20   31  p
# 4           audi      a4    2.0  2008    4    auto(av)   f    21   30  p
# 5           audi      a4    2.8  1999    6    auto(l5)   f    16   26  p
# ..           ...     ...    ...   ...  ...         ...  ..   ...  ... ..
# 230   volkswagen  passat    2.0  2008    4    auto(s6)   f    19   28  p
# 231   volkswagen  passat    2.0  2008    4  manual(m6)   f    21   29  p
# 232   volkswagen  passat    2.8  1999    6    auto(l5)   f    16   26  p
# 233   volkswagen  passat    2.8  1999    6  manual(m5)   f    18   26  p
# 234   volkswagen  passat    3.6  2008    6    auto(s6)   f    17   26  p
#
#          cls
# 1    compact
# 2    compact
# 3    compact
# 4    compact
# 5    compact
# ...

# %%
#summary
mpg.describe()
# Out:
#             displ         year         cyl        city         hwy
# count  234.000000   234.000000  234.000000  234.000000  234.000000
# mean     3.471795  2003.500000    5.888889   16.858974   23.440171
# std      1.291959     4.509646    1.611534    4.255946    5.954643
# min      1.600000  1999.000000    4.000000    9.000000   12.000000
# 25%      2.400000  1999.000000    4.000000   14.000000   18.000000
# 50%      3.300000  2003.500000    6.000000   17.000000   24.000000
# 75%      4.600000  2008.000000    8.000000   19.000000   27.000000
# max      7.000000  2008.000000    8.000000   35.000000   44.000000

# %%
#how many manufacturers?
mpg.manufacturer.nunique()
# Out:
# 15

# %%
#how many models?
mpg.model.nunique()
# Out:
# 38

# %%
#create a milage difernce col
mpg['mileage_difference'] = mpg.hwy - mpg.city
mpg
# Out:
#     manufacturer   model  displ  year  cyl       trans drv  city  hwy fl  \
# 1           audi      a4    1.8  1999    4    auto(l5)   f    18   29  p
# 2           audi      a4    1.8  1999    4  manual(m5)   f    21   29  p
# 3           audi      a4    2.0  2008    4  manual(m6)   f    20   31  p
# 4           audi      a4    2.0  2008    4    auto(av)   f    21   30  p
# 5           audi      a4    2.8  1999    6    auto(l5)   f    16   26  p
# ..           ...     ...    ...   ...  ...         ...  ..   ...  ... ..
# 230   volkswagen  passat    2.0  2008    4    auto(s6)   f    19   28  p
# 231   volkswagen  passat    2.0  2008    4  manual(m6)   f    21   29  p
# 232   volkswagen  passat    2.8  1999    6    auto(l5)   f    16   26  p
# 233   volkswagen  passat    2.8  1999    6  manual(m5)   f    18   26  p
# 234   volkswagen  passat    3.6  2008    6    auto(s6)   f    17   26  p
#
#          cls  mileage_difference
# 1    compact                  11
# ...

# %%
#create average milage
mpg['average_mileage'] = (mpg.hwy + mpg.city) / 2
mpg
# Out:
#     manufacturer   model  displ  year  cyl       trans drv  city  hwy fl  \
# 1           audi      a4    1.8  1999    4    auto(l5)   f    18   29  p
# 2           audi      a4    1.8  1999    4  manual(m5)   f    21   29  p
# 3           audi      a4    2.0  2008    4  manual(m6)   f    20   31  p
# 4           audi      a4    2.0  2008    4    auto(av)   f    21   30  p
# 5           audi      a4    2.8  1999    6    auto(l5)   f    16   26  p
# ..           ...     ...    ...   ...  ...         ...  ..   ...  ... ..
# 230   volkswagen  passat    2.0  2008    4    auto(s6)   f    19   28  p
# 231   volkswagen  passat    2.0  2008    4  manual(m6)   f    21   29  p
# 232   volkswagen  passat    2.8  1999    6    auto(l5)   f    16   26  p
# 233   volkswagen  passat    2.8  1999    6  manual(m5)   f    18   26  p
# 234   volkswagen  passat    3.6  2008    6    auto(s6)   f    17   26  p
#
#          cls  mileage_difference  average_mileage
# ...

# %%
# create an is automatic col
mpg['is_automatic'] = mpg.trans.str.contains('auto')
#mpg.trans.apply(lambda x: 'auto' in x)
mpg
# Out:
#     manufacturer   model  displ  year  cyl       trans drv  city  hwy fl  \
# 1           audi      a4    1.8  1999    4    auto(l5)   f    18   29  p
# 2           audi      a4    1.8  1999    4  manual(m5)   f    21   29  p
# 3           audi      a4    2.0  2008    4  manual(m6)   f    20   31  p
# 4           audi      a4    2.0  2008    4    auto(av)   f    21   30  p
# 5           audi      a4    2.8  1999    6    auto(l5)   f    16   26  p
# ..           ...     ...    ...   ...  ...         ...  ..   ...  ... ..
# 230   volkswagen  passat    2.0  2008    4    auto(s6)   f    19   28  p
# 231   volkswagen  passat    2.0  2008    4  manual(m6)   f    21   29  p
# 232   volkswagen  passat    2.8  1999    6    auto(l5)   f    16   26  p
# 233   volkswagen  passat    2.8  1999    6  manual(m5)   f    18   26  p
# 234   volkswagen  passat    3.6  2008    6    auto(s6)   f    17   26  p
#
#          cls  mileage_difference  average_mileage  is_automatic
# ...

# %%
#manufcaturer with the best mpg
mpg.groupby('manufacturer').mean().average_mileage.nlargest(1)
# Out:
# manufacturer
# honda    28.5
# Name: average_mileage, dtype: float64

# %%
# do automatics or manuals get better mpg?
mpg.groupby('is_automatic').mean().average_mileage
# Out:
# is_automatic
# False    22.227273
# True     19.130573
# Name: average_mileage, dtype: float64

# %% [markdown]
# ## Part 3

# %%
# use function to get data and explore chipotle
url = get_db_url(user,password,host,'chipotle')

# %%
df = pd.read_sql('select * from orders', url)
df.head()
# Out:
#    id  order_id  quantity                              item_name  \
# 0   1         1         1           Chips and Fresh Tomato Salsa
# 1   2         1         1                                   Izze
# 2   3         1         1                       Nantucket Nectar
# 3   4         1         1  Chips and Tomatillo-Green Chili Salsa
# 4   5         2         2                           Chicken Bowl
#
#                                                            choice_description  \
# 0                                                                         nan
# 1                                                                [Clementine]
# 2                                                                     [Apple]
# 3                                                                         nan
# 4  [Tomatillo-Red Chili Salsa (Hot), [Black Beans, Rice, Cheese, Sour Cream]]
#
#   item_price
# 0     $2.39
# 1     $3.39
# 2     $3.39
# 3     $2.39
# 4    $16.98

# %%
#total price for each order
df.item_price = df.item_price.str.strip('$').astype(float)

# %%
df.groupby('order_id').item_price.sum()
# Out:
# order_id
# 1       11.56
# 2       16.98
# 3       12.67
# 4       21.00
# 5       13.70
#         ...
# 1830    23.00
# 1831    12.90
# 1832    13.20
# 1833    23.50
# 1834    28.75
# Name: item_price, Length: 1834, dtype: float64

# %%
#most popular 3 items
df.groupby('item_name')['quantity'].sum().nlargest(3)
# Out:
# item_name
# Chicken Bowl           761
# Chicken Burrito        591
# Chips and Guacamole    506
# Name: quantity, dtype: int64

# %%
#which item produced the most revenue?
df [df.item_name == 'Chicken Bowl'].sort_values('quantity', ascending=False).head()
# Out:
#         id  order_id  quantity     item_name  \
# 409    410       178         3  Chicken Bowl
# 1514  1515       616         3  Chicken Bowl
# 4        5         2         2  Chicken Bowl
# 4435  4436      1767         2  Chicken Bowl
# 415    416       181         2  Chicken Bowl
#
#                                                                              choice_description  \
# 409   [[Fresh Tomato Salsa (Mild), Tomatillo-Green Chili Salsa (Medium), Roasted Chili Corn ...
# 1514                     [Fresh Tomato Salsa, [Rice, Black Beans, Cheese, Sour Cream, Lettuce]]
# 4                    [Tomatillo-Red Chili Salsa (Hot), [Black Beans, Rice, Cheese, Sour Cream]]
# 4435                                 [Fresh Tomato Salsa, [Rice, Pinto Beans, Cheese, Lettuce]]
# 415                                                                 [Tomatillo Red Chili Salsa]
#
#       item_price
# 409        32.94
# 1514       26.25
# 4          16.98
# 4435       17.50
# 415        17.50

# %%
#join employees and titles df together
emp_titles = pd.merge(df1,df2, how='inner', on='emp_no')
emp_titles.head()
# Out:
#    emp_no  birth_date first_name last_name gender   hire_date  \
# 0   10001  1953-09-02     Georgi   Facello      M  1986-06-26
# 1   10002  1964-06-02    Bezalel    Simmel      F  1985-11-21
# 2   10003  1959-12-03      Parto   Bamford      M  1986-08-28
# 3   10004  1954-05-01  Chirstian   Koblick      M  1986-12-01
# 4   10004  1954-05-01  Chirstian   Koblick      M  1986-12-01
#
#              title   from_date     to_date
# 0  Senior Engineer  1986-06-26  9999-01-01
# 1            Staff  1996-08-03  9999-01-01
# 2  Senior Engineer  1995-12-03  9999-01-01
# 3         Engineer  1986-12-01  1995-12-01
# 4  Senior Engineer  1995-12-01  9999-01-01

# %%
#For each title
# find the hire date of the employee that was hired most recently with that title
emp_titles.groupby('title').hire_date.max()
# Out:
# title
# Assistant Engineer    1999-12-24
# Engineer              2000-01-28
# Manager               1992-02-05
# Senior Engineer       2000-01-01
# Senior Staff          2000-01-13
# Staff                 2000-01-12
# Technique Leader      1999-12-31
# Name: hire_date, dtype: object

# %%
url = get_db_url(user,password,host,'employees')
pd.read_sql('''select title, max(hire_date) from employees
                join titles using (emp_no)
                group by title
            ''', url)
# Out:
#                 title max(hire_date)
# 0     Senior Engineer     2000-01-01
# 1               Staff     2000-01-12
# 2            Engineer     2000-01-28
# 3        Senior Staff     2000-01-13
# 4  Assistant Engineer     1999-12-24
# 5    Technique Leader     1999-12-31
# 6             Manager     1992-02-05

# %%
#Write the code necessary to create a cross tabulation of the 
#number of titles by department.
emp_titles
# Out:
#         emp_no  birth_date first_name last_name gender   hire_date  \
# 0        10001  1953-09-02     Georgi   Facello      M  1986-06-26
# 1        10002  1964-06-02    Bezalel    Simmel      F  1985-11-21
# 2        10003  1959-12-03      Parto   Bamford      M  1986-08-28
# 3        10004  1954-05-01  Chirstian   Koblick      M  1986-12-01
# 4        10004  1954-05-01  Chirstian   Koblick      M  1986-12-01
# ...        ...         ...        ...       ...    ...         ...
# 443303  499997  1961-08-03    Berhard    Lenart      M  1986-04-21
# 443304  499997  1961-08-03    Berhard    Lenart      M  1986-04-21
# 443305  499998  1956-09-05   Patricia   Breugel      M  1993-10-13
# 443306  499998  1956-09-05   Patricia   Breugel      M  1993-10-13
# 443307  499999  1958-05-01     Sachin   Tsukuda      M  1997-11-30
#
#                   title   from_date     to_date
# 0       Senior Engineer  1986-06-26  9999-01-01
# 1                 Staff  1996-08-03  9999-01-01
# ...

# %%
dept_emp = pd.read_sql("""
                    select * 
                    from dept_emp
                        join departments
                            using (dept_no)
                    """, url)

# %%
all_emps = pd.merge(emp_titles, dept_emp, how='inner', on='emp_no')
all_emps.head()
# Out:
#    emp_no  birth_date first_name last_name gender   hire_date  \
# 0   10001  1953-09-02     Georgi   Facello      M  1986-06-26
# 1   10002  1964-06-02    Bezalel    Simmel      F  1985-11-21
# 2   10003  1959-12-03      Parto   Bamford      M  1986-08-28
# 3   10004  1954-05-01  Chirstian   Koblick      M  1986-12-01
# 4   10004  1954-05-01  Chirstian   Koblick      M  1986-12-01
#
#              title from_date_x   to_date_x dept_no from_date_y   to_date_y  \
# 0  Senior Engineer  1986-06-26  9999-01-01    d005  1986-06-26  9999-01-01
# 1            Staff  1996-08-03  9999-01-01    d007  1996-08-03  9999-01-01
# 2  Senior Engineer  1995-12-03  9999-01-01    d004  1995-12-03  9999-01-01
# 3         Engineer  1986-12-01  1995-12-01    d004  1986-12-01  9999-01-01
# 4  Senior Engineer  1995-12-01  9999-01-01    d004  1986-12-01  9999-01-01
#
#      dept_name
# 0  Development
# 1        Sales
# 2   Production
# 3   Production
# 4   Production

# %%
pd.crosstab(all_emps.title, all_emps.dept_name)
# Out:
# dept_name           Customer Service  Development  Finance  Human Resources  \
# title
# Assistant Engineer               298         7769        0                0
# Engineer                        2362        58135        0                0
# Manager                            4            2        2                2
# Senior Engineer                 2027        49326        0                0
# Senior Staff                   13925         1247    12139            12274
# Staff                          16150         1424    13929            14342
# Technique Leader                 309         7683        0                0
#
# dept_name           Marketing  Production  Quality Management  Research  Sales
# title
# Assistant Engineer          0        6445                1831       378      0
# Engineer                    0       49649               13852      2986      0
# Manager                     2           4                   4         2      2
# ...
